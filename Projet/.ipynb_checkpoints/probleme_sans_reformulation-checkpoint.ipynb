# %%
import Pkg
Pkg.add("JuMP")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`

# %%
Pkg.add("DelimitedFiles")
# Out:
#   Resolving package versions...
# Updating `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
#   [8bb1440f] + DelimitedFiles
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`

# %%
using NBInclude
using JuMP
using Gurobi
using DelimitedFiles
const GUROBI_ENV = Gurobi.Env()
const L = 6
# Out:
# Academic license - for non-commercial use only - expires 2021-06-28
# WARNING: redefinition of constant GUROBI_ENV. This may fail, cause incorrect answers, or produce other errors.
# 6

# %%
@nbinclude("dataparser.ipynb")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\aebou\.julia\environments\v1.5\Manifest.toml`
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.8946720411011612cx, 0.03797031076520908cy), (-0.0513774828277466cx, 0.7371441066951167cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.8889952437144686cx, -0.004239703661997163cy), (-0.2959909393278939cx, -0.46259711482120175cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.8870142571211477cx, 0.0023783674213219887cy), (0.08265319871817979cx, -0.17125672739272388cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.9299106857902453cx, 0.05589677461279175cy), (0.9237468589746489cx, 0.9558068628024637cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.2724463206244243cx, -0.4542402051558728cy), (0.8890038993441112cx, -0.004262062934388685cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.34426353114086616cx, -0.5020852398657357cy), (-0.4925686559313103cx, -0.656551739023083cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.35531845954604746cx, -0.4849486333375758cy), (-0.2955464201727034cx, -0.4637977280663956cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.2710952169189614cx, -0.45830121993276546cy), (-0.2132620769873989cx, -0.4421246252254369cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.2794853738681711cx, -0.4421790113868379cy), (0.005283645602173016cx, -0.20860889150533646cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.3477324116703072cx, -0.4983467960492683cy), (-0.6153562026090946cx, -0.7193538749134689cy)])  …  Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.9634861290988699cx, -0.8106345120101812cy), (0.07596794532795137cx, -0.2054790299772213cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.9558686417534258cx, -0.833176078763055cy), (-0.6053014533400083cx, -0.7498502312949104cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.9674587522192676cx, -0.805628498052392cy), (0.07400869016203858cx, 0.015387308543241201cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.9981583628492017cx, -0.7913757593330727cy), (0.9252858005031863cx, 0.9558442147323275cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.7282587559453845cx, -0.9600493133207805cy), (-0.06802258981446224cx, 0.7234600933658507cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.7073267573189785cx, -0.9808470122525351cy), (-0.2973808450748963cx, -0.4976934436459193cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.7182682910520058cx, -0.9665532712203161cy), (0.06834077264482918cx, -0.2140287261663413cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.7036659111011442cx, -0.9921371074010926cy), (-0.6059437334177129cx, -0.7553576580561275cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.722426742849822cx, -0.9633716117064609cy), (0.0661956888014979cx, 0.008661966798055275cy)]), Compose.LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.7510354211920245cx, -0.9559765148119933cy), (0.9195637314303773cx, 0.9559765148119933cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitiv ...

# %%
#FONCTIONS A AJOUTER

# Recuperation des arcs
function getEdge(kep)
    edge_list = Array{Array{Int64,1},1}()
    for (ind,arc) in enumerate(edges(kep))
            push!(edge_list,[src(arc), dst(arc)])
    end
    return edge_list
end

getEdge(pool)

#Recuperation de tous les chemins de longueur L+1
function getPath_L(pool)
    all_path = simplecycles_hawick_james(pool) #Recuperation de tous les chemins du graphe
    path_L=[]
    L=6
    for i in all_path #Recuperation des chemins de longueur L+1 dans path_L
        if length(i) == L+1
            push!(path_L, i)
        end
    end
    return path_L
end
# Out:
# getPath_L (generic function with 1 method)

# %%
# Le probleme

# Le modèle : choisir un des 2 selon votre ORDI
#model = Model()

model=Model(optimizer_with_attributes(() -> Gurobi.Optimizer(GUROBI_ENV)))
set_optimizer_attribute(model, "OutputFlag", 0) #???? parametre a modifier

# Le solver
#statut = set_optimizer(model, GLPK.Optimizer)

# Les donnees
path_L = getPath_L(pool)

#Ensemble des arcs sous la forme [i,j]
edge_list = getEdge(pool); #Penser a ajouter la fonction PROBLEME_SANS_REFORMULATION

#Nombre de sommets
E = ne(pool)
V = nv(pool)

#Les variables
@variable(model, x[i in 1:E, j in 1:E], Bin)

#La fonction objective
@objective(model, Max, sum(x[e[1],e[2]] for e in 1:E))

#les contraintes
#Premiere contrainte
for i in 1:V
    E_1 = [] #Ensemble des arcs ou i est le depart
    E_2 = [] #Ensemble des arcs ou i est l arrivee
    #Recuperer les arcs ou il y a i en extremite
    for e in edge_list
        if e[1] == i
            push!(E_1, e[2])
        end
        if e[2] == i
            push!(E_2, e[1])
        end
    end
    #La contrainte sur le sommet i
    @constraint(model, sum(x[e, i] for e in E_2) == sum(x[i, e for e in E_1)))
end

#Deuxieme contrainte
for i in 1:V
    E_i = [] #Ensemble des arcs ou i est l arrivee
    #Recuperer les arcs ou il y a i en extremite
    for e in 1:E
        if e[1] == i
            push!(E_i, e[2])
        end
    end
    #La contrainte sur le sommet i
    @constraint(model, sum(x[i, e[2]] for e in 1:E_i) <= 1)
end

#Troisieme contrainte
for p in path_L #Pour tous les chemins de longueur L+1
    @constraint(model, sum(x[p[j], p[j+1]] for j in 1:L) <= L-1)
end
# Out:
# BoundsError
#
# Stacktrace:
#  [1] getindex(::Int64, ::Int64) at .\number.jl:78
#  [2] macro expansion at C:\Users\aebou\.julia\packages\MutableArithmetics\bPWR4\src\rewrite.jl:276 [inlined]
#  [3] macro expansion at C:\Users\aebou\.julia\packages\JuMP\y5vgk\src\macros.jl:928 [inlined]
#  [4] top-level scope at .\In[50]:26
#  [5] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
